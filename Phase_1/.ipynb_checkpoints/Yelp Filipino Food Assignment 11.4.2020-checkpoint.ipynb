# %%
import pandas as pd
import numpy as np
import requests
import json
#from yelp.client import Client
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
url = 'https://api.yelp.com/v3/businesses/search'
response = requests.get(url)

# %%
MY_API_KEY = "YGBpB3w3LYRSlwQUguL1JAPJ61B0Xk5Ijcu4e9ladrLY3hlKYE-9TE8puomqEgVIDs2t6-XsBi7quTpQWmsqElYHu61bGITMhoYOdjTV13ZfNF65p4PjMOQDV5-hX3Yx"


term = 'Filipino Food'
location = 'Manhattan'
SEARCH_LIMIT = 30

url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(MY_API_KEY),
    }

url_params = {
                'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit': SEARCH_LIMIT
            }
response = requests.get(url, headers=headers, params=url_params)

# %%
response.status_code
# Out:
# 200

# %%
print(response)
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '{"businesses": [{"id": "9mWw-sK4RjSPYRHQN_S9ZQ", "alias": "tradisyon-new-york-2", "name": "Tradisyon", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/RrW9ZkZJzSXAIz3vQc8ZWQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/tradisyon-new-york-2?adjust_creative=zC0jVarRey036PgvnxUw6g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC0jVarRey036PgvnxUw6g", "review_count": 72, "categories": [{"alias": "filipino", "title": "Filipino"}, {"alias": "comfortfood", "title": "Comfort Food"}], "rating": 4.5, "coordinates": {"latitude": 40.76491, "longitude": -73.987537}, "transactions": ["delivery", "pickup"], "location": {"address1": "790 9th Ave", "address2": null, "address3": "", "city": "New York", "zip_code": "10019", "country": "US", "state": "NY", "display_address": ["790 9th Ave", "New York, NY 10019"]}, "phone": "+16468666900", "display_phone": "(646) 866-6900", "distance": 926.363658668446}, {"id": "-b3J-5K_beWyGxQ1Id7KQg", "alias": "jeepney-new
# ...

# %%
json.loads(response.text)
# Out:
# {'businesses': [{'id': '9mWw-sK4RjSPYRHQN_S9ZQ',
#    'alias': 'tradisyon-new-york-2',
#    'name': 'Tradisyon',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RrW9ZkZJzSXAIz3vQc8ZWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tradisyon-new-york-2?adjust_creative=zC0jVarRey036PgvnxUw6g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC0jVarRey036PgvnxUw6g',
#    'review_count': 72,
#    'categories': [{'alias': 'filipino', 'title': 'Filipino'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76491, 'longitude': -73.987537},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '790 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['790 9th Ave', 'New York, NY 10019']},
#    'phone': '+16468666900',
# ...

# %%
Filipino_Food = response.text
Filipino_Food = json.loads(Filipino_Food)

# %%
Filipino_Food
# Out:
# {'businesses': [{'id': '9mWw-sK4RjSPYRHQN_S9ZQ',
#    'alias': 'tradisyon-new-york-2',
#    'name': 'Tradisyon',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RrW9ZkZJzSXAIz3vQc8ZWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tradisyon-new-york-2?adjust_creative=zC0jVarRey036PgvnxUw6g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=zC0jVarRey036PgvnxUw6g',
#    'review_count': 72,
#    'categories': [{'alias': 'filipino', 'title': 'Filipino'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76491, 'longitude': -73.987537},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '790 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['790 9th Ave', 'New York, NY 10019']},
#    'phone': '+16468666900',
# ...

# %%
for key in Filipino_Food.keys():
    print(key)
# Out:
# businesses
# total
# region

# %%
len(Filipino_Food['businesses'])
# Out:
# 30

# %%
filipinofood_df = pd.DataFrame(Filipino_Food['businesses'])
filipinofood_df.head()
# Out:
#                        id                           alias  \
# 0  9mWw-sK4RjSPYRHQN_S9ZQ            tradisyon-new-york-2
# 1  -b3J-5K_beWyGxQ1Id7KQg                jeepney-new-york
# 2  j_ZW3vvpjLDG34nBq5f-UA               grill-21-new-york
# 3  YAOJAXBqQTHuY85kN8VulQ  mama-finas-new-york-new-york-2
# 4  nxTEuWKzkK1tCF4LrhFSUQ           pig-and-khao-new-york
#
#                      name                                          image_url  \
# 0               Tradisyon  https://s3-media4.fl.yelpcdn.com/bphoto/RrW9Zk...
# 1                 Jeepney  https://s3-media2.fl.yelpcdn.com/bphoto/Oj0uKh...
# 2                Grill 21  https://s3-media1.fl.yelpcdn.com/bphoto/5hFrsI...
# 3  Mama Fina's - New York  https://s3-media1.fl.yelpcdn.com/bphoto/5qM9vU...
# 4            Pig and Khao  https://s3-media4.fl.yelpcdn.com/bphoto/lVUEbZ...
#
#    is_closed                                                url  review_count  \
# ...

# %%
#What Filipino Restaurants do delivery?

# %%
filipinofood_df.describe
# Out:
# <bound method NDFrame.describe of                         id                                     alias  \
# 0   9mWw-sK4RjSPYRHQN_S9ZQ                      tradisyon-new-york-2
# 1   -b3J-5K_beWyGxQ1Id7KQg                          jeepney-new-york
# 2   j_ZW3vvpjLDG34nBq5f-UA                         grill-21-new-york
# 3   YAOJAXBqQTHuY85kN8VulQ            mama-finas-new-york-new-york-2
# 4   nxTEuWKzkK1tCF4LrhFSUQ                     pig-and-khao-new-york
# 5   vznxVKO25CwAYTOWU4BGLw                         meryenda-new-york
# 6   hKtSEqh8fLgLneDdZZwF8w              kusina-pinoy-bistro-woodside
# 7   deGWrCulECC2mYKDIbQYwA                          tsismis-new-york
# 8   MudZO8HTIUUEH8zjb9Hn5A         bilao-filipino-cuisine-new-york-5
# 9   8WnHtvMdPWE66eSkUdbLhQ                      flip-sigi-new-york-2
# 10  fvAPtk-nOfDFjXdLZGd7TA                       jollibee-new-york-2
# 11  NXZFu7KHBrG02gzYneY5Xg                     ugly-kitchen-new-york
# ...

# %%
filipinofood_df['rating'].head
# Out:
# <bound method NDFrame.head of 0     4.5
# 1     4.0
# 2     4.0
# 3     4.0
# 4     4.0
# 5     4.5
# 6     4.5
# 7     4.0
# 8     4.0
# 9     4.0
# 10    4.0
# 11    4.0
# 12    3.5
# 13    4.0
# 14    4.0
# 15    3.5
# 16    3.5
# 17    3.5
# 18    4.5
# 19    3.5
# 20    4.0
# 21    4.5
# 22    3.5
# 23    4.5
# 24    4.0
# 25    4.5
# 26    3.5
# 27    4.0
# 28    3.5
# 29    4.0
# Name: rating, dtype: float64>

# %%
plt.hist(filipinofood_df['rating'])
plt.title('Filipino Restaurant Rating in NYC')
plt.xlabel('Ratings')
plt.ylabel('Number of Restaurants')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
